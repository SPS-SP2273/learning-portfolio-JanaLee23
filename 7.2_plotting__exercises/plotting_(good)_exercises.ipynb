# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Good) Exercises</span></div>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Exercise 1

# %%
#--------- Generate cosine and sine values --------#
x = np.linspace(-np.pi, np.pi, num=100, endpoint=True)
cos_x = np.cos(x)
sin_x = np.sin(x)
fun1_x = np.exp(-x) * np.cos(5 * x)
fun2_x = np.exp(-x) * np.sin(2 * x)

#------- Plot the data -------#
fig, axes = plt.subplots(nrows=2, ncols=2,
                         figsize=(12, 8),  sharey='row', sharex='col')

#------- Subplot 1 -------#
axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
axes[0, 0].plot(x, cos_x**2, color='r',
                linestyle=':', label='$\cos^2 x$')
axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
axes[0, 0].set_ylabel('Cosine Value')
axes[0, 0].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[0, 0].set_xticklabels([])
axes[0, 0].set_xlim([-np.pi, np.pi])
axes[0, 0].fill_between(x, cos_x, -25, color='r', alpha=.125)
axes[0, 0].legend(loc='upper right', frameon=True)

#------- Subplot 2 -------#
axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
axes[0, 1].fill_between(x, sin_x, -25, color='g', alpha=.125)
axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
axes[0, 1].set_title('$\sin x$ & $\sin^2x$')
axes[0, 1].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[0, 1].set_xticklabels([])
axes[0, 1].set_xlim([-np.pi, np.pi])
axes[0, 1].set_ylim(-1.25, 1.25)
axes[0, 1].legend(loc='upper right', frameon=True)

#------- Subplot 3 -------#
axes[1, 0].plot(x, fun1_x, color='b', label='$\sin 2x$')
axes[1, 0].fill_between(x, fun1_x, -25, color='b', alpha=.125)
axes[1, 0].set_title('$e^{-x}\cos 5x$')
axes[1, 0].set_xlabel('Angle (radians)')
axes[1, 0].set_ylabel('Cosine Value')
axes[1, 0].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
axes[1, 0].set_yticks([-25, -20, -15, -10, -5, 0, 5, 10])
axes[1, 0].set_ylim(-27.5, 15)
axes[1, 0].legend(loc='upper right', frameon=True)

#------- Subplot 4 -------#
axes[1, 1].plot(x, fun2_x, color='y', label='$\sin 2x$')
axes[1, 1].set_title('$e^{-x}\sin 2x$')
axes[1, 1].fill_between(x, fun2_x, -25, color='y', alpha=.125)
axes[1, 1].set_xlabel('Angle (radians)')
axes[1, 1].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 1].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
axes[1, 1].set_xlim([-np.pi, np.pi])
axes[1, 1].set_yticks([-25, -20, -15, -10, -5, 0, 5, 10])
axes[1, 1].set_ylim(-27.5, 15)
axes[1, 1].legend(loc='upper right', frameon=True)


# 'flatten', 'opens' the 2D array into a simple 1D array
for a in axes.flatten():
    a.grid(alpha=.5)

plt.tight_layout()
plt.savefig('after_trig_functions.jpg', dpi=300)
plt.show(block=False)
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\c'
# <>:15: SyntaxWarning: invalid escape sequence '\c'
# <>:16: SyntaxWarning: invalid escape sequence '\c'
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# <>:27: SyntaxWarning: invalid escape sequence '\s'
# <>:28: SyntaxWarning: invalid escape sequence '\s'
# <>:36: SyntaxWarning: invalid escape sequence '\s'
# <>:38: SyntaxWarning: invalid escape sequence '\c'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:48: SyntaxWarning: invalid escape sequence '\s'
# <>:49: SyntaxWarning: invalid escape sequence '\s'
# <>:53: SyntaxWarning: invalid escape sequence '\p'
# <>:53: SyntaxWarning: invalid escape sequence '\p'
# <>:53: SyntaxWarning: invalid escape sequence '\p'
# <>:53: SyntaxWarning: invalid escape sequence '\p'
# <>:13: SyntaxWarning: invalid escape sequence '\c'
# <>:15: SyntaxWarning: invalid escape sequence '\c'
# <>:16: SyntaxWarning: invalid escape sequence '\c'
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# <>:27: SyntaxWarning: invalid escape sequence '\s'
# <>:28: SyntaxWarning: invalid escape sequence '\s'
# <>:36: SyntaxWarning: invalid escape sequence '\s'
# <>:38: SyntaxWarning: invalid escape sequence '\c'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\p'
# <>:48: SyntaxWarning: invalid escape sequence '\s'
# <>:49: SyntaxWarning: invalid escape sequence '\s'
# <>:53: SyntaxWarning: invalid escape sequence '\p'
# <>:53: SyntaxWarning: invalid escape sequence '\p'
# <>:53: SyntaxWarning: invalid escape sequence '\p'
# <>:53: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\leeyi\AppData\Local\Temp\ipykernel_27628\1273086381.py:13: SyntaxWarning: invalid escape sequence '\c'
#   axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
# C:\Users\leeyi\AppData\Local\Temp\ipykernel_27628\1273086381.py:15: SyntaxWarning: invalid escape sequence '\c'
#   linestyle=':', label='$\cos^2 x$')
# C:\Users\leeyi\AppData\Local\Temp\ipykernel_27628\1273086381.py:16: SyntaxWarning: invalid escape sequence '\c'
#   axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
# C:\Users\leeyi\AppData\Local\Temp\ipykernel_27628\1273086381.py:25: SyntaxWarning: invalid escape sequence '\s'
#   axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
# C:\Users\leeyi\AppData\Local\Temp\ipykernel_27628\1273086381.py:27: SyntaxWarning: invalid escape sequence '\s'
#   axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
# C:\Users\leeyi\AppData\Local\Temp\ipykernel_27628\1273086381.py:28: SyntaxWarning: invalid escape sequence '\s'
#   axes[0, 1].set_title('$\sin x$ & $\sin^2x$')
# C:\Users\leeyi\AppData\Local\Temp\ipykernel_27628\1273086381.py:36: SyntaxWarning: invalid escape sequence '\s'
#   axes[1, 0].plot(x, fun1_x, color='b', label='$\sin 2x$')
# C:\Users\leeyi\AppData\Local\Temp\ipykernel_27628\1273086381.py:38: SyntaxWarning: invalid escape sequence '\c'
#   axes[1, 0].set_title('$e^{-x}\cos 5x$')
# C:\Users\leeyi\AppData\Local\Temp\ipykernel_27628\1273086381.py:42: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# C:\Users\leeyi\AppData\Local\Temp\ipykernel_27628\1273086381.py:42: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# C:\Users\leeyi\AppData\Local\Temp\ipykernel_27628\1273086381.py:42: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# C:\Users\leeyi\AppData\Local\Temp\ipykernel_27628\1273086381.py:42: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# C:\Users\leeyi\AppData\Local\Temp\ipykernel_27628\1273086381.py:48: SyntaxWarning: invalid escape sequence '\s'
#   axes[1, 1].plot(x, fun2_x, color='y', label='$\sin 2x$')
# C:\Users\leeyi\AppData\Local\Temp\ipykernel_27628\1273086381.py:49: SyntaxWarning: invalid escape sequence '\s'
#   axes[1, 1].set_title('$e^{-x}\sin 2x$')
# C:\Users\leeyi\AppData\Local\Temp\ipykernel_27628\1273086381.py:53: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 1].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# C:\Users\leeyi\AppData\Local\Temp\ipykernel_27628\1273086381.py:53: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 1].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# C:\Users\leeyi\AppData\Local\Temp\ipykernel_27628\1273086381.py:53: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 1].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# C:\Users\leeyi\AppData\Local\Temp\ipykernel_27628\1273086381.py:53: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 1].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
