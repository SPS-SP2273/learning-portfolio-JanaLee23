# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Good) Exercises</span></div>

# %% [markdown]
# # Exercise 1

# %% [markdown]
# Task 1

# %%
name = str(input("What is your name?"))
print(f"How you doin \033[1m{name.upper()}\033[0m!")

# %% [markdown]
# Task 2

# %%
name = str(input("What is your name?"))
age = str(input("What is your age?"))
print(f"My name is \033[1m{name.upper()}\033[0m and I am \033[1m{age}\033[0m years old.")

# %% [markdown]
# Task 3

# %%
pi = 3.141592653589793

print(f"The value of pi to 2 decimal places is: {pi:.2f}")
print(f"The value of pi to 3 decimal places is: {pi:.3f}")
print(f"The value of pi to 4 decimal places is: {pi:.4f}")

# %% [markdown]
# Task 4

# %%
table = [["Apple", "0.99"],      
         ["Banana", "0.59"],
         ["Orange", "1.29"]
        ]

for fruit, price in table:
    print(f"{fruit:<10} ${price:>5}")
print()
print("********** $*****")
# Out:
# Apple      $ 0.99
# Banana     $ 0.59
# Orange     $ 1.29
#
# ********** $*****

# %% [markdown]
# # Exercise 2

# %%
def get_letter_grade(score):
    if 0 <= score <= 100:
        if score >= 70:
            return 'A'
        elif score >= 50:
            return 'B'
        elif score >= 35:
            return 'C'
        else:
            return 'Fail'
    else:
        return 'Undefined'

try:
    user_input = input("Enter the student's score: ")
    numeric_score = float(user_input)
    grade = get_letter_grade(numeric_score)
    if grade == 'Undefined':
        print("Invalid input. Please enter a numerical value from 0 to 100.")
    else:
        print(f"The student's letter grade is: {grade}")
except ValueError:
    print("Invalid input. Please enter a numerical value.")
# Out:
# The student's letter grade is: A

# %% [markdown]
# # Exercise 3

# %%
def factorial(n):
    if n < 0:
        return "Invalid input"
    elif n == 0:
        return 1
    else:
        result = 1
        for number in range(1, n+1):
            result *= number
        return result


print(factorial(5))   # Testing, expected output: 120
print(factorial(-1))  # Testing, expected output: Invalid input
# Out:
# 120
# Invalid input
