# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 Functions

# %%
print('Hello world!')

# %% [markdown]
# - print() is a function.
# You can think of a function as ‘something’ that does a specific task. In this case, the print() function accepts the “Hello world” argument and prints it to the screen.
# - Parentheses, (), always follow a function.
# We use these parentheses to pass arguments to the function. Most functions expect arguments; the parentheses are left empty for those functions that don’t require an argument (e.g. exit()).
# - print() is a core (in-built) function of Python.
# We can also define our own functions. This is an extremely powerful feature, which we will explore later.
# - The above is an example of what we call code; instructions written using a syntax that a programming language understands.

# %% [markdown]
# # 2 Python is interpreted

# %%
print('Hello World')
print('Hello World again')

# %% [markdown]
# # 3 Python is sensitive.

# %%
print('Hello World')      # This WILL work
Print('Hello World')      # This will NOT work

# %% [markdown]
# # 4 Comments

# %%
# This is a comment
print('One')              # This is a comment.
# print('Two')            # The interpreter ignores this line.
print('Three')            # This is
                          # also a way to
                          # write comments
# Out:
# One
# Three

# %% [markdown]
# # 5 = is not the same as ==

# %%
name = 'Batman'

if name == 'Batman':
    print('Hello Batman!')
else:
    print('Hello World!')
# Out:
# Hello Batman!

# %% [markdown]
# # 6 Use if to make decisions

# %% [markdown]
# # 7 Indentations (spaces) are sooo IMPORTANT!

# %% [markdown]
# - Indentations play a crucial role in Python; do not use them indiscriminately.
# - : is used to designate a block of code.

# %% [markdown]
# # 8 ‘age’ is English, age is a variable.

# %%
## How to print another variable type within a string
age = 10
print(f"my age is {age}")

# %%
print("Hello world", "hehe", sep = " meow", end = " end")

# %% [markdown]
# # 9 Brackets

# %%
print('Hello!')             # In functions

(1 + 2) * 5                 # For math

py_list = [1, 2, 3, 4, 5]   # A 1D list

py_list_2 = [               # A 2D list
                [1, "A"],      
                [2, "B"],
                [3, "C"],
                [4, "D"],
                [5, "E"]
            ]

personal_info = {
    'Names': 'Batman',
    'Real Name': 'Bruce Wayne',
    'Age': 55,
    'Affiliation': 'Justice League',
    'Universe': 'DC'
}

print(personal_info['Real Name'])
# Out:
# Hello!
# Bruce Wayne

# %% [markdown]
# # 10 Giving Python superpowers with Packages

# %%
## numpy package for sqrt is for larger datasets
import math
import numpy

math.sqrt(4)
numpy.sqrt([4,9])

# %%
## How to import everything from a package

from numpy import *

## How to import a specfiic function from a package
from numpy import sqrt 

## How to simplify referring to the packages
import numpy as np

# %% [markdown]
# ## 10.1 Some Context

# %%
print("Hello")
1 * ((2 - 3) + 4) ** 5 / 6  #since this is the last expression
                            #it is displayed as output (jupyter thing)
# Out:
# Hello
# 40.5

# %% [markdown]
# ## 10.2 Importing the math package

# %%
import math         # Adding(importing) the functions
                    # of the 'math' package    
math.sqrt(4)
# Out:
# 2.0

# %% [markdown]
# ## 10.3 Importing the numpy package

# %%
import numpy as np    # Importing Numpy and giving 
                      # it an alias np 
                      # because I am lazy

np.sqrt(4)
# Out:
# np.float64(2.0)

# %% [markdown]
# ## 10.4 Why so many packages?

# %%
np.sqrt([4, 9, 16])

# %% [markdown]
# # 11 The dot (.)

# %%
# Dot Indicates ownership

"I am Batman".split()

# "1234.split()" Does not work since split() doesn't work for numbers
# Out:
# ['I', 'am', 'Batman']

# %% [markdown]
# ## Footnotes
